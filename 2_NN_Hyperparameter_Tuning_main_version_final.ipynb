# %%
# Importing t
import pandas as pd
from pandas import read_csv
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
X = array[:,0:8]
y = array[:,8]

# %%
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -6.476301e-17 -9.251859e-18  1.503427e-17  1.006140e-16 -3.006854e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.590520e-16  2.451743e-16  1.931325e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
# !pip install tensorflow==2.12.0
# !pip install keras==2.12.0
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.64.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.11.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.4.26)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.43.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.13.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Requirement already satisfied: keras==2.12.0 in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, kernel_initializer='random_uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='random_uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='random_uniform', activation='sigmoid'))

    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-10-0efede6617b0>:2: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.753 total time=   3.1s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.714 total time=   4.3s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.760 total time=   2.9s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.837 total time=   2.7s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.752 total time=   2.6s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.753 total time=  11.6s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.714 total time=  11.7s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.786 total time=   7.7s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.837 total time=  12.5s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.765 total time=  12.2s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.740 total time=  15.6s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.708 total time=  22.1s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.792 total time=  13.8s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.837 total time=  16.0s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.778 total time=  21.9s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.747 total time=   1.7s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.714 total time=   1.8s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.760 total time=   2.5s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.843 total time=   2.4s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.758 total time=   1.9s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.753 total time=   4.0s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.721 total time=   4.4s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.773 total time=   6.8s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.863 total time=   6.4s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.771 total time=   6.7s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.753 total time=  12.6s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.708 total time=  11.5s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.773 total time=   7.7s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.850 total time=   8.9s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.758 total time=   8.6s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END .....batch_size=40, epochs=10;, score=0.766 total time=   1.6s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END .....batch_size=40, epochs=10;, score=0.714 total time=   1.5s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END .....batch_size=40, epochs=10;, score=0.786 total time=   1.8s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END .....batch_size=40, epochs=10;, score=0.804 total time=   1.7s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END .....batch_size=40, epochs=10;, score=0.765 total time=   1.8s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END .....batch_size=40, epochs=50;, score=0.760 total time=   3.9s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END .....batch_size=40, epochs=50;, score=0.708 total time=   4.1s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END .....batch_size=40, epochs=50;, score=0.760 total time=   3.2s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END .....batch_size=40, epochs=50;, score=0.843 total time=   4.5s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END .....batch_size=40, epochs=50;, score=0.758 total time=   6.0s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ....batch_size=40, epochs=100;, score=0.753 total time=  11.4s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ....batch_size=40, epochs=100;, score=0.701 total time=   4.2s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ....batch_size=40, epochs=100;, score=0.760 total time=   4.7s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ....batch_size=40, epochs=100;, score=0.843 total time=   5.9s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.771 total time=   4.2s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7761480331420898, using {'batch_size': 20, 'epochs': 50}
# 0.763101601600647,0.04006275224791655 with: {'batch_size': 10, 'epochs': 10}
# 0.7709107875823975,0.04022761611501709 with: {'batch_size': 10, 'epochs': 50}
# 0.7709277749061585,0.04413479367899563 with: {'batch_size': 10, 'epochs': 100}
# 0.764417290687561,0.04262142433431348 with: {'batch_size': 20, 'epochs': 10}
# 0.7761480331420898,0.04716990286780638 with: {'batch_size': 20, 'epochs': 50}
# 0.7683218717575073,0.04611205458930704 with: {'batch_size': 20, 'epochs': 100}
# 0.7669722437858582,0.029993556903454822 with: {'batch_size': 40, 'epochs': 10}
# 0.7657159805297852,0.043537520865324045 with: {'batch_size': 40, 'epochs': 50}
# 0.7657329559326171,0.045531011543316666 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-12-baa4aca7ee54>:19: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.727 total time=   1.7s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.695 total time=   1.6s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.766 total time=   1.5s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.797 total time=   4.6s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.660 total time=   3.2s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.760 total time=   2.3s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.714 total time=   1.8s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.760 total time=   1.5s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.810 total time=   1.7s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.752 total time=   2.0s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.714 total time=   3.0s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.584 total time=   2.0s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.630 total time=   1.5s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.745 total time=   1.7s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.745 total time=   1.9s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.753 total time=   2.1s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.584 total time=   3.0s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.766 total time=   3.0s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.797 total time=   2.0s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.765 total time=   2.2s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.747 total time=   1.8s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.701 total time=   2.0s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.760 total time=   2.3s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.817 total time=   2.1s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.765 total time=   1.8s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.753 total time=   1.9s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.584 total time=   1.9s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.740 total time=   1.8s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.830 total time=   3.0s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.758 total time=   2.0s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.649 total time=   2.8s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.649 total time=   2.2s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.760 total time=   2.1s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.804 total time=   2.6s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.758 total time=   3.0s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.649 total time=   2.0s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.721 total time=   1.8s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.701 total time=   2.0s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.817 total time=   2.2s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.739 total time=   1.9s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.649 total time=   2.5s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.584 total time=   2.0s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.786 total time=   2.8s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.824 total time=   1.9s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.771 total time=   2.1s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7591715455055237, using {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7291656136512756,0.0489449725978809 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7591715455055237,0.030667408292066635 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.683753502368927,0.065161295524049 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7331975102424622,0.0758186353419542 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7578983187675477,0.03706669808696189 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7332314729690552,0.08074022018472647 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7241066098213196,0.06320981700494388 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7253968358039856,0.05467784518089373 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7228503465652466,0.0905497475459625 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-14-fb0aeae9a03b>:17: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=0.649 total time=   3.8s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=0.584 total time=   2.2s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=0.630 total time=   1.9s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=0.745 total time=   2.3s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=0.647 total time=   2.4s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/12] END activation_function=softmax, init=normal;, score=0.649 total time=   2.6s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/12] END activation_function=softmax, init=normal;, score=0.416 total time=   2.1s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/12] END activation_function=softmax, init=normal;, score=0.370 total time=   2.2s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/12] END activation_function=softmax, init=normal;, score=0.745 total time=   2.0s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/12] END activation_function=softmax, init=normal;, score=0.353 total time=   3.3s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/12] END activation_function=softmax, init=zero;, score=0.351 total time=   2.0s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/12] END activation_function=softmax, init=zero;, score=0.584 total time=   3.4s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/12] END activation_function=softmax, init=zero;, score=0.370 total time=   2.3s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/12] END activation_function=softmax, init=zero;, score=0.745 total time=   2.1s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/12] END activation_function=softmax, init=zero;, score=0.353 total time=   2.3s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/12] END activation_function=relu, init=uniform;, score=0.649 total time=   2.0s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/12] END activation_function=relu, init=uniform;, score=0.617 total time=   2.5s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/12] END activation_function=relu, init=uniform;, score=0.630 total time=   2.7s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/12] END activation_function=relu, init=uniform;, score=0.810 total time=   1.8s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/12] END activation_function=relu, init=uniform;, score=0.647 total time=   2.1s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/12] END activation_function=relu, init=normal;, score=0.773 total time=   2.0s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/12] END activation_function=relu, init=normal;, score=0.714 total time=   3.5s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/12] END activation_function=relu, init=normal;, score=0.630 total time=   3.3s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/12] END activation_function=relu, init=normal;, score=0.824 total time=   1.7s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/12] END activation_function=relu, init=normal;, score=0.765 total time=   1.8s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/12] END activation_function=relu, init=zero;, score=0.649 total time=   2.4s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/12] END activation_function=relu, init=zero;, score=0.584 total time=   2.1s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/12] END activation_function=relu, init=zero;, score=0.630 total time=   3.3s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/12] END activation_function=relu, init=zero;, score=0.745 total time=   3.0s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/12] END activation_function=relu, init=zero;, score=0.647 total time=   2.1s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/12] END activation_function=tanh, init=uniform;, score=0.747 total time=   1.6s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/12] END activation_function=tanh, init=uniform;, score=0.714 total time=   1.6s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/12] END activation_function=tanh, init=uniform;, score=0.753 total time=   2.1s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/12] END activation_function=tanh, init=uniform;, score=0.824 total time=   3.2s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/12] END activation_function=tanh, init=uniform;, score=0.771 total time=   3.4s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/12] END activation_function=tanh, init=normal;, score=0.753 total time=   2.0s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/12] END activation_function=tanh, init=normal;, score=0.682 total time=   2.4s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/12] END activation_function=tanh, init=normal;, score=0.760 total time=   1.9s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/12] END activation_function=tanh, init=normal;, score=0.810 total time=   1.8s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/12] END activation_function=tanh, init=normal;, score=0.765 total time=   3.2s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/12] END activation_function=tanh, init=zero;, score=0.649 total time=   2.0s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/12] END activation_function=tanh, init=zero;, score=0.584 total time=   2.4s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/12] END activation_function=tanh, init=zero;, score=0.630 total time=   2.0s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/12] END activation_function=tanh, init=zero;, score=0.745 total time=   1.8s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/12] END activation_function=tanh, init=zero;, score=0.647 total time=   1.7s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 10/12] END activation_function=linear, init=uniform;, score=0.747 total time=   2.5s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform;, score=0.682 total time=   1.7s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 10/12] END activation_function=linear, init=uniform;, score=0.753 total time=   3.0s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 10/12] END activation_function=linear, init=uniform;, score=0.830 total time=   2.3s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 10/12] END activation_function=linear, init=uniform;, score=0.771 total time=   2.2s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 11/12] END activation_function=linear, init=normal;, score=0.779 total time=   2.2s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 11/12] END activation_function=linear, init=normal;, score=0.675 total time=   2.6s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 11/12] END activation_function=linear, init=normal;, score=0.747 total time=   1.5s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 11/12] END activation_function=linear, init=normal;, score=0.804 total time=   1.6s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 11/12] END activation_function=linear, init=normal;, score=0.771 total time=   2.0s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 12/12] END activation_function=linear, init=zero;, score=0.649 total time=   1.8s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 12/12] END activation_function=linear, init=zero;, score=0.584 total time=   2.3s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 12/12] END activation_function=linear, init=zero;, score=0.630 total time=   2.6s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 12/12] END activation_function=linear, init=zero;, score=0.745 total time=   2.5s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 12/12] END activation_function=linear, init=zero;, score=0.647 total time=   3.5s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7618113994598389, using {'activation_function': 'tanh', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.5066208362579345,0.15986120648539123 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.4806468069553375,0.15882346717152127 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.6707240462303161,0.07086635464335658 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7410236835479737,0.06548769935113019 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7618113994598389,0.035935602146282775 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7539937138557434,0.04134198893120881 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7566250801086426,0.047564825101576724 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7552924275398254,0.043953387769287734 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-16-4101f7719a68>:17: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.766 total time=   1.6s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.701 total time=   1.6s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.753 total time=   1.6s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.784 total time=   1.5s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.732 total time=   1.5s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.760 total time=   2.2s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.682 total time=   2.1s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.740 total time=   1.5s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.797 total time=   1.5s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.778 total time=   1.5s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.753 total time=   1.8s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.682 total time=   2.4s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.747 total time=   2.1s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.817 total time=   2.2s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.758 total time=   1.5s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.753 total time=   1.5s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.675 total time=   1.5s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.753 total time=   1.6s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.797 total time=   1.5s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.765 total time=   1.5s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.760 total time=   2.2s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.675 total time=   2.2s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.747 total time=   1.4s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.837 total time=   1.5s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.771 total time=   2.7s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.760 total time=   1.5s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.714 total time=   1.5s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.760 total time=   1.7s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.830 total time=   3.4s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.784 total time=   1.8s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.760 total time=   4.0s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.708 total time=   1.8s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.766 total time=   1.5s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.804 total time=   2.1s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.771 total time=   2.3s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.760 total time=   1.5s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.701 total time=   1.5s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.747 total time=   2.5s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.824 total time=   1.6s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.765 total time=   1.5s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.766 total time=   2.0s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.714 total time=   2.4s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.766 total time=   1.5s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.817 total time=   1.5s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.758 total time=   1.5s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7696290612220764, using {'neuron1': 8, 'neuron2': 8}
# 0.7474238157272339,0.028681697444925273 with: {'neuron1': 4, 'neuron2': 2}
# 0.7513963222503662,0.03961252123991037 with: {'neuron1': 4, 'neuron2': 4}
# 0.7513963222503662,0.042930099484368815 with: {'neuron1': 4, 'neuron2': 8}
# 0.748781931400299,0.0401291147198269 with: {'neuron1': 8, 'neuron2': 2}
# 0.7579322695732117,0.05161049609408115 with: {'neuron1': 8, 'neuron2': 4}
# 0.7696290612220764,0.03775354052005503 with: {'neuron1': 8, 'neuron2': 8}
# 0.7617859244346619,0.03099714725308502 with: {'neuron1': 16, 'neuron2': 2}
# 0.7592055082321167,0.039182549884095585 with: {'neuron1': 16, 'neuron2': 4}
# 0.764383327960968,0.03262836465517104 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 20,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# <ipython-input-18-d1f6b07ee5f5>:19: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 20,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 24/24 [==============================] - 0s 4ms/step
# 0.77734375

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))

    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
